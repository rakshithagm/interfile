# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\gmrak\Desktop\data.csv")

# %%
data.head(3)
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9 ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33 ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244 ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85 ...    57    64
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
#
# [3 rows x 180 columns]

# %%
data.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# std      161.328725    161.467837    162.11912    162.03336    160.436352
# min    -1757.000000  -1832.000000  -1778.00000  -1840.00000  -1867.000000
# 25%      -54.000000    -54.000000    -55.00000    -55.00000    -54.000000
# 50%       -8.000000     -8.000000     -8.00000     -7.00000     -7.000000
# 75%       36.000000     35.000000     36.00000     36.00000     35.250000
# max     1816.000000   2047.000000   2047.00000   2047.00000   2047.000000
#
#            ...               X170          X171          X172          X173  \
# count      ...       11500.000000  11500.000000  11500.000000  11500.000000
# mean       ...         -10.145739    -11.630348    -12.943478    -13.668870
# std        ...         164.652883    166.149790    168.554058    168.556486
# min        ...       -1867.000000  -1865.000000  -1642.000000  -1723.000000
# 25%        ...         -55.000000    -56.000000    -56.000000    -56.000000
# 50%        ...          -9.000000    -10.000000    -10.000000    -10.000000
# 75%        ...          34.000000     34.000000     33.000000     33.000000
# max        ...        1777.000000   1472.000000   1319.000000   1436.000000
#
#                X174          X175          X176          X177          X178  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -13.363304    -13.045043    -12.705130    -12.426000    -12.195652
# std      167.257290    164.241019    162.895832    162.886311    164.852015
# min    -1866.000000  -1863.000000  -1781.000000  -1727.000000  -1829.000000
# 25%      -55.000000    -56.000000    -55.000000    -55.000000    -55.000000
# 50%      -10.000000     -9.000000     -9.000000     -9.000000     -9.000000
# 75%       34.000000     34.000000     34.000000     34.000000     34.000000
# max     1733.000000   1958.000000   2047.000000   2047.000000   1915.000000
#
#                   y
# count  11500.000000
# mean       3.000000
# std        1.414275
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
#
# [8 rows x 179 columns]

# %%
data.tail(3)
# Out:
#        Unnamed: 0  X1  X2  X3  X4  X5  X6  X7  X8  X9 ...  X170  X171  X172  \
# 11497    X8.V1.28  14   6 -13 -16  10  26  27  -9   4 ...   -65   -48   -61
# 11498  X10.V1.932 -40 -25  -9 -12  -2  12   7  19  22 ...   121   135   148
# 11499  X16.V1.210  29  41  57  72  74  62  54  43  31 ...   -59   -25    -4
#
#        X173  X174  X175  X176  X177  X178  y
# 11497   -62   -67   -30    -2    -1    -8  5
# 11498   143   116    86    68    59    55  3
# 11499     2     5     4    -2     2    20  4
#
# [3 rows x 180 columns]

# %%
a=data.iloc[:,-1]
a.head(3)
# Out:
# 0    4
# 1    1
# 2    5
# Name: y, dtype: int64

# %%
b=data.sort_values(by="y")
b.head(3)
# Out:
#        Unnamed: 0    X1    X2    X3    X4    X5   X6   X7   X8   X9 ...  X170  \
# 10145   X7.V1.117  -362  -327  -229   -56   148  318  416  514  630 ...  -497
# 6388   X20.V1.924 -1839 -1838 -1835 -1687 -1186 -836 -698 -656 -727 ...   -82
# 6384   X18.V1.316   -62    -4    30    40    36   34   43   52   56 ...   243
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# 10145  -518  -529  -543  -526  -487  -395  -224    85  1
# 6388     15    91   134   172   208   247   287   314  1
# 6384    242   223   175   100    14   -97  -172  -212  1
#
# [3 rows x 180 columns]

# %%
sorted_data=b.set_index('Unnamed: 0')
sorted_data.head(3)
# Out:
#               X1    X2    X3    X4    X5   X6   X7   X8   X9  X10 ...  X170  \
# Unnamed: 0                                                        ...
# X7.V1.117   -362  -327  -229   -56   148  318  416  514  630  760 ...  -497
# X20.V1.924 -1839 -1838 -1835 -1687 -1186 -836 -698 -656 -727 -988 ...   -82
# X18.V1.316   -62    -4    30    40    36   34   43   52   56   60 ...   243
#
#             X171  X172  X173  X174  X175  X176  X177  X178  y
# Unnamed: 0
# X7.V1.117   -518  -529  -543  -526  -487  -395  -224    85  1
# X20.V1.924    15    91   134   172   208   247   287   314  1
# X18.V1.316   242   223   175   100    14   -97  -172  -212  1
#
# [3 rows x 179 columns]

# %%
sorted_data.index.name= None
sorted_data.head(3)
# Out:
#               X1    X2    X3    X4    X5   X6   X7   X8   X9  X10 ...  X170  \
# X7.V1.117   -362  -327  -229   -56   148  318  416  514  630  760 ...  -497
# X20.V1.924 -1839 -1838 -1835 -1687 -1186 -836 -698 -656 -727 -988 ...   -82
# X18.V1.316   -62    -4    30    40    36   34   43   52   56   60 ...   243
#
#             X171  X172  X173  X174  X175  X176  X177  X178  y
# X7.V1.117   -518  -529  -543  -526  -487  -395  -224    85  1
# X20.V1.924    15    91   134   172   208   247   287   314  1
# X18.V1.316   242   223   175   100    14   -97  -172  -212  1
#
# [3 rows x 179 columns]

# %%
sorted_data.index.name="Unnamed: 0"
sorted_data.reset_index(inplace=True)
sorted_data.head(3)
# Out:
#    Unnamed: 0    X1    X2    X3    X4    X5   X6   X7   X8   X9 ...  X170  \
# 0   X7.V1.117  -362  -327  -229   -56   148  318  416  514  630 ...  -497
# 1  X20.V1.924 -1839 -1838 -1835 -1687 -1186 -836 -698 -656 -727 ...   -82
# 2  X18.V1.316   -62    -4    30    40    36   34   43   52   56 ...   243
#
#    X171  X172  X173  X174  X175  X176  X177  X178  y
# 0  -518  -529  -543  -526  -487  -395  -224    85  1
# 1    15    91   134   172   208   247   287   314  1
# 2   242   223   175   100    14   -97  -172  -212  1
#
# [3 rows x 180 columns]

# %%
sorted_data1=sorted_data
sorted_data1.head(3)
# Out:
#    Unnamed: 0    X1    X2    X3    X4    X5   X6   X7   X8   X9 ...  X170  \
# 0   X7.V1.117  -362  -327  -229   -56   148  318  416  514  630 ...  -497
# 1  X20.V1.924 -1839 -1838 -1835 -1687 -1186 -836 -698 -656 -727 ...   -82
# 2  X18.V1.316   -62    -4    30    40    36   34   43   52   56 ...   243
#
#    X171  X172  X173  X174  X175  X176  X177  X178  y
# 0  -518  -529  -543  -526  -487  -395  -224    85  1
# 1    15    91   134   172   208   247   287   314  1
# 2   242   223   175   100    14   -97  -172  -212  1
#
# [3 rows x 180 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed: 0 to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
data.iloc[1].head(3)
# Out:
# Unnamed: 0    X15.V1.924
# X1                   386
# X2                   382
# Name: 1, dtype: object

# %%
features=data.drop("Unnamed: 0",axis=1)
features.head(3)
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10 ...  X170  X171  X172  \
# 0  135  190  229  223  192  125   55   -9  -33  -38 ...   -17   -15   -31
# 1  386  382  356  331  320  315  307  272  244  232 ...   164   150   146
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94 ...    57    64    48
#
#    X173  X174  X175  X176  X177  X178  y
# 0   -77  -103  -127  -116   -83   -51  4
# 1   152   157   156   154   143   129  1
# 2    19   -12   -30   -35   -35   -36  5
#
# [3 rows x 179 columns]

# %%
feature=features.drop("y",axis=1)
data1=feature.head(3)
data1
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...   X169  X170  X171  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...      8   -17   -15
# 1  386  382  356  331  320  315  307  272  244  232  ...    168   164   150
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...     29    57    64
#
#    X172  X173  X174  X175  X176  X177  X178
# 0   -31   -77  -103  -127  -116   -83   -51
# 1   146   152   157   156   154   143   129
# 2    48    19   -12   -30   -35   -35   -36
#
# [3 rows x 178 columns]

# %%
label1=feature.iloc[1]
label1.plot(kind='line')
plt.xlabel('Samples')
plt.ylabel('class1')
plt.show()

# %%
label2=feature.iloc[7]
label2.plot(kind='line')
plt.xlabel('Samples')
plt.ylabel('class2')
plt.show()

# %%
label3=feature.iloc[12]
label3.plot(kind='line')
plt.xlabel('Samples')
plt.ylabel('class3')
plt.show()

# %%
label4=feature.iloc[0]
label4.plot(kind='line')
plt.xlabel('Samples')
plt.ylabel('class4')
plt.show()

# %%
label5=feature.iloc[2]
label5.plot(kind='line')
plt.xlabel('Samples')
plt.ylabel('class5')
plt.show()

# %%
d=np.array(feature.iloc[0:11499])
d
# Out:
# array([[ 135,  190,  229, ..., -116,  -83,  -51],
#        [ 386,  382,  356, ...,  154,  143,  129],
#        [ -32,  -39,  -47, ...,  -35,  -35,  -36],
#        ...,
#        [ -47,  -11,   28, ...,   77,  117,  170],
#        [  14,    6,  -13, ...,   -2,   -1,   -8],
#        [ -40,  -25,   -9, ...,   68,   59,   55]], dtype=int64)

# %%
count1=0
count2=0
count3=0
count4=0
count5=0
features.iloc[:,-1]
a=features.iloc[:,-1]
for k in range(11500):
    if a[k]==1:
        count1=count1+1
    elif a[k]==2:
        count2=count2+1
    elif a[k]==3:
        count3=count3+1
    elif a[k]==4:
        count4=count4+1
    elif a[k]==5:
        count5=count5+1

print(count1)
print(count2)
print(count3)
print(count4)
print(count5)
# Out:
# 2300
# 2300
# 2300
# 2300
# 2300

# %%
X = data.iloc[:,1:179].values
X.shape
# Out:
# (11500, 178)

# %%
plt.subplot(511)
plt.plot(X[1,:])
plt.title('5 Classes')
plt.ylabel('all 5 types')
plt.subplot(512)
plt.plot(X[7,:])
plt.subplot(513)
plt.plot(X[12,:])
plt.subplot(514)
plt.plot(X[0,:])
plt.subplot(515)
plt.plot(X[2,:])
plt.xlabel('Samples')
plt.show()

# %%
plt.subplot(511)
plt.plot(d[1,:])
plt.title('Classes')
plt.ylabel('class 1')
plt.subplot(512)
plt.plot(d[22,:])
plt.subplot(513)
plt.plot(d[23,:])
plt.subplot(514)
plt.plot(d[81,:])
plt.subplot(515)
plt.plot(d[82,:])
plt.xlabel('Samples')
plt.show()

# %%
plt.subplot(511)
plt.plot(d[7,:])
plt.title('Classes')
plt.ylabel('class 2')
plt.subplot(512)
plt.plot(d[14,:])
plt.subplot(513)
plt.plot(d[16,:])
plt.subplot(514)
plt.plot(d[19,:])
plt.subplot(515)
plt.plot(d[28,:])
plt.xlabel('Samples')
plt.show()

# %%
plt.subplot(511)
plt.plot(d[12,:])
plt.title('Classes')
plt.ylabel('class 3')
plt.subplot(512)
plt.plot(d[15,:])
plt.subplot(513)
plt.plot(d[17,:])
plt.subplot(514)
plt.plot(d[25,:])
plt.subplot(515)
plt.plot(d[71,:])
plt.xlabel('Samples')
plt.show()

# %%
plt.subplot(511)
plt.plot(d[80,:])
plt.title('Classes')
plt.ylabel('class 4')
plt.subplot(512)
plt.plot(d[6,:])
plt.subplot(513)
plt.plot(d[9,:])
plt.subplot(514)
plt.plot(d[13,:])
plt.subplot(515)
plt.plot(d[18,:])
plt.xlabel('Samples')
plt.show()

# %%
plt.subplot(511)
plt.plot(d[2,:])
plt.title('Classes')
plt.ylabel('class 5')
plt.subplot(512)
plt.plot(d[3,:])
plt.subplot(513)
plt.plot(d[4,:])
plt.subplot(514)
plt.plot(d[5,:])
plt.subplot(515)
plt.plot(d[26,:])
plt.xlabel('Samples')
plt.show()

# %%
#checking for similarities within classes
plt.plot(d[1,:])
plt.show()
plt.plot(d[7,:])
plt.show()
plt.plot(d[12,:])
plt.show()
plt.plot(d[0,:])
plt.show()
plt.plot(d[2,:])
plt.show()

# %%
x=b.groupby(["y"]).mean()
x
# Out:
#           X1         X2         X3         X4         X5         X6  \
# y
# 1 -21.936522 -19.049130 -15.293913  -9.836087  -3.707391   2.730000
# 2  -7.710000  -8.148696  -8.020000  -8.050435  -7.776957  -8.220870
# 3  -9.207391  -9.276522  -9.968261 -10.634348 -11.172174 -11.559130
# 4 -12.726087 -12.410435 -12.272609 -12.096957 -12.083043 -12.349130
# 5  -6.326957  -5.673043  -5.380870  -5.097391  -5.309130  -5.618261
#
#           X7         X8         X9        X10    ...           X169  \
# y                                                ...
# 1   6.899565   7.425652   8.380870  10.773913    ...      -7.266522
# 2  -8.597826  -9.210000  -9.217826  -9.347826    ...      -7.979565
# 3 -11.797826 -12.013043 -12.132609 -12.249130    ...     -13.590000
# 4 -13.064348 -13.419565 -13.441739 -13.147826    ...     -13.428696
# 5  -5.950000  -6.218696  -6.378696  -6.871304    ...      -5.229565
#
#         X170       X171       X172       X173       X174       X175  \
# y
# 1  -9.714783 -15.909565 -22.383043 -26.424783 -26.221739 -25.830870
# 2  -8.483043  -8.967391  -9.067391  -8.924783  -8.592174  -8.524348
# 3 -13.332174 -13.218696 -12.789565 -12.366087 -11.320000 -10.455217
# 4 -13.636522 -14.114783 -14.404783 -14.251304 -14.109565 -13.653913
# 5  -5.562174  -5.941304  -6.072609  -6.377391  -6.573043  -6.760870
#
#         X176       X177       X178
# y
# 1 -25.043913 -24.548261 -24.016522
# 2  -8.558696  -8.187391  -8.147391
# 3  -9.757391  -9.418696  -8.935217
# 4 -13.082174 -12.791739 -12.914783
# 5  -7.083478  -7.183913  -6.964348
#
# [5 rows x 178 columns]

# %%
class1=x.iloc[0]
class1.plot(kind='line')
plt.show()

# %%
class2=x.iloc[1]
class2.plot(kind='line')
plt.show()

# %%
class3=x.iloc[2]
class3.plot(kind='line')
plt.show()

# %%
class4=x.iloc[3]
class4.plot(kind='line')
plt.show()

# %%
class5=x.iloc[4]
class5.plot(kind='line')
plt.show()

# %%
print(class1.min())
print(class1.max())
# Out:
# -26.4247826087
# 12.3208695652

# %%
print(class2.min())
print(class2.max())
# Out:
# -10.5230434783
# -1.13086956522

# %%
print(class3.min())
print(class3.max())
# Out:
# -13.59
# -4.68173913043

# %%
print(class4.min())
print(class4.max())
# Out:
# -14.5243478261
# -9.96130434783

# %%
print(class5.min())
print(class5.max())
# Out:
# -7.77086956522
# -4.83

# %%
cols = data.columns
output = data.y
output[output>1]=0
ax = sn.countplot(output,label="Count")
plt.show()
non_seizure, seizure = output.value_counts()
print(non_seizure)
print(seizure)
# Out:
# C:\Users\gmrak\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 9200
# 2300

# %%
#logistic regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap

import seaborn as sns

from sklearn.datasets import load_breast_cancer

# %matplotlib inline

# %%
feature.head(3)
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...   X169  X170  X171  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...      8   -17   -15
# 1  386  382  356  331  320  315  307  272  244  232  ...    168   164   150
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...     29    57    64
#
#    X172  X173  X174  X175  X176  X177  X178
# 0   -31   -77  -103  -127  -116   -83   -51
# 1   146   152   157   156   154   143   129
# 2    48    19   -12   -30   -35   -35   -36
#
# [3 rows x 178 columns]

# %%
a=np.array(feature)
a
# Out:
# array([[ 135,  190,  229, ..., -116,  -83,  -51],
#        [ 386,  382,  356, ...,  154,  143,  129],
#        [ -32,  -39,  -47, ...,  -35,  -35,  -36],
#        ...,
#        [  14,    6,  -13, ...,   -2,   -1,   -8],
#        [ -40,  -25,   -9, ...,   68,   59,   55],
#        [  29,   41,   57, ...,   -2,    2,   20]], dtype=int64)

# %%
b= data.iloc[:,179].values
b
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
b[b>1]=0
b
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
b = b.reshape(-1, 1)

# %%
plt.plot(a, b, 'r.')
plt.show()

# %%
scaler = MinMaxScaler()
a = scaler.fit_transform(a)
b = scaler.fit_transform(b)
# Out:
# C:\Users\gmrak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
a_train, a_test, b_train, b_test = train_test_split(a, b, test_size=0.2)

# %%
classifier = LogisticRegression(random_state = 0)
classifier.fit(a_train, b_train)
# Out:
# C:\Users\gmrak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
b_pred = classifier.predict(a_test)

# %%
cm = confusion_matrix(b_test, b_pred)
cm
# Out:
# array([[1859,    0],
#        [ 425,   16]], dtype=int64)

# %%
plt.plot(a_train, b_train, 'r.', a_test, b_pred, 'b.')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(a_train, b_train)
y_pred_log_reg = clf.predict(a_test)
acc_log_reg = round(clf.score(a_train, b_train) * 100, 2)
print (str(acc_log_reg) + ' %')
# Out:
# C:\Users\gmrak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 80.8 %

# %%
#svm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
m = np.array(features)
n = data.iloc[:,179].values

# %%
m_train, m_test, n_train, n_test = train_test_split(m, n, test_size = 0.25, random_state = 0)

# %%
sc = StandardScaler()
m_train = sc.fit_transform(m_train)
m_test = sc.transform(m_test)
# Out:
# C:\Users\gmrak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(m_train, n_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
n_pred = classifier.predict( m_test)

# %%
cm = confusion_matrix(n_test, n_pred)
cm
# Out:
# array([[2312,    0],
#        [   0,  563]], dtype=int64)

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(m_train, n_train)
y_pred_svc = clf.predict(m_test)
acc_svc = round(clf.score(m_train, n_train) * 100, 2)
print (str(acc_svc) + '%')
# Out:
# 99.62%
